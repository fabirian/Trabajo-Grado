# %%
# !pip install spacy

# %%
# !python -m spacy download es_core_news_sm
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.9/12.9 MB 35.0 MB/s eta 0:00:00
# ...
# ✔ Download and installation successful
# You can now load the package via spacy.load('es_core_news_sm')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %%
import pandas as pd
import spacy

# %%
# Cargar el archivo CSV
file_path = '/content/metadato_img_frontales.csv'
df = pd.read_csv(file_path)

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7973 entries, 0 to 7972
# Data columns (total 36 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Unnamed: 0                       7973 non-null   int64
#  1   ImageID                          7973 non-null   object
#  2   ImageDir                         7973 non-null   int64
#  3   StudyDate_DICOM                  7973 non-null   int64
#  4   StudyID                          7973 non-null   object
#  5   PatientID                        7973 non-null   object
#  6   PatientBirth                     7973 non-null   float64
#  7   PatientSex_DICOM                 7973 non-null   object
#  8   ViewPosition_DICOM               4854 non-null   object
#  9   Projection                       7973 non-null   object
#  10  MethodProjection                 7973 non-null   object
#  11  Pediatric                        7973 non-null   object
# ...

# %%
# Nombre de la columna a completar
nombre_columna = 'Report'

# %%
df['Report']
# Out:
# 0                      sin hallazg patolog edad pacient .
# 1        cambi pulmonar cronic sever . sign fibrosis b...
# 2        . . siluet cardi mediastin dentr normal . cam...
# 3        cabez cuell humeral derech apreci lesion suge...
# 4                      sin alter radiolog significacion .
#                               ...
# 7968     masa conoc con sign cavitacion lsi respect es...
# 7969     . . hallazg . . . . marc aument siluet cardio...
# 7970     pequen infiltr intersticial infrahili derech ...
# 7971     hili prominent orig vascul . probabl infiltr ...
# 7972     mejori radiolog con respect anterior estudi r...
# Name: Report, Length: 7973, dtype: object

# %%
# Cargar el modelo de spaCy en español
nlp = spacy.load("es_core_news_sm")

# %%
# Diccionario de completaciones
palabras_posibles = {'sin': 'sin', 'hallazg': 'hallazgo', 'patolog': 'patológico','edad': 'edad',
    'pacient': 'paciente', 'cambi': 'cambio', 'pulmonar': 'pulmonar', 'cronic': 'crónica', 'sever': 'severo',
    'sign': 'signo', 'fibrosis': 'fibrosis', 'bibasal': 'bibasal', 'sutil': 'sutil', 'infiltr': 'infiltración',
    'pseudonodul': 'pseudonodular', 'milimetr': 'milimetro', 'vidri': 'vidrio', 'deslustr': 'deslustre',
    'localiz': 'localizado', 'bas': 'basica', 'cifosis': 'cifosis', 'siluet': 'silueta', 'cardi': 'cardíaco',
    'mediastin': 'mediastino', 'dentr': 'dentro', 'normal': 'normal', 'sen': '', 'costofren': 'constofrenico',
    'libr': '', 'no': 'no', 'enfermed': 'enfermedad', 'metastas': 'metastasis', 'cabez': 'cabeza', 'cuell': 'cuello',
    'humeral': 'humeral', 'derech': 'derecho', 'apreci': 'apreciación', 'lesion': 'lesión', 'sugest': 'sugestion',
    'encondrom': 'encondroma', 'respect': 'respecto', 'estudi': 'estudio', 'previ': 'previo', '14': '14', '9': '9',
    '15': '15', 'aument': 'aumento', 'anterosuperior': 'anterosuperior', 'relacion': 'relacion', 'con': 'con',
    'elongacion': 'elongacion', 'tronc': 'tronco', 'supraaort': 'supraaórtico', 'vs': 'versus', 'boci': 'bocio', 'degener': 'degeneración',
    'ose': 'óseo', 'osteofitosis': 'osteofitosis', 'escoliosis': 'escoliosis', 'dors': 'dorsal',
    'lumb': 'lumbar', 'aortic': 'aórtico', 'alter': 'alteración', 'radiolog': 'radiológico',
    'significacion': 'significación', 'signific': 'significativo', 'epoc': 'EPOC', 'atrap': 'atrapamiento',
    'aere': 'aérea', 'ni': 'ni', 'condens': 'condensación', 'dorsolumb': 'dorsolumbar',
    'ateromatosis': 'ateromatosis', 'imagen': 'imagen', 'pequen': 'pequeña', 'taman': 'tamaño',
    'redond': 'redonda', 'densid': 'densidad', 'metal': 'metálico', 'proyect': 'proyectil', 'torax': 'tórax', 'hombre': 'hombre', 'i': 'índice',
    'probabl': 'probable', 'perdigon': 'perdigón', 'compresion': 'compresión', 'par': 'par', 'lateral': 'lateral',
    'izquierd': 'izquierda', 'traque': 'tráquea', 'estructur': 'estructura', 'vascular': 'vascular',
    'hipoventilacion': 'hipoventilación', 'cardiomediastin': 'cardiome-diastínico', 'parenquim': 'parénquima',
    'pulmon': 'pulmón', 'via': 'vía', 'central': 'central', 'trav': 'través', 'ven': 'vena', 'subclavi': 'subclavicular',
    'extrem': 'extremidad', 'distal': 'distal', 'cav': 'cavidad', 'superior': 'superior', 'mecan': 'mecanismo',
    'column': 'columna', 'axial': 'axial', 'relev': 'relevancia', 'hili': 'hilio', 'prominent': 'prominente',
    'orig': 'origen', 'vascul': 'vascular', 'retrocardiac': 'retrocardíaco', 'objet': 'objeto', 'catet': 'catéter',
    'venos': 'venoso', 'inici': 'inició', 'auricul': 'auricular', 'necesari': 'necesario', 'dat': 'dato',
    'clinic': 'clínica', 'correlacion': 'correlación', 'marcapas': 'marcapasos', 'tricameral': 'tricameral',
    'identific': 'identificó', 'neumotorax': 'neumotórax', 'atelectasi': 'atelectasia', 'acun': 'acúneo',
    'vertebral': 'vertebral', 'anterior': 'anterior', 'liger': 'ligero', 'mejori': 'mejoría',
    'posterobasal': 'posterobasal', 'descrit': 'descrito', 'dia': 'día', '11': '11', 'febrer': 'febrero',
    'herni': 'hernia', 'hiat': 'hiato', 'inter': 'intersticial', 'lobulacion': 'lobulación', 'posterior': 'posterior', 'diafragm': 'diafragma', 'discret': 'discreto',
    'lii': 'lii', 'analit': 'analítica', 'calcif': 'calcificación', 'localizacion': 'localización',
    'ambos': 'ambos', 'tendon': 'tendón', 'supraespin': 'supraespinoso', 'sugier': 'sugiere',
    'tendinopati': 'tendinopatía', 'aparent': 'aparente', 'cardiomegali': 'cardiomegalia',
    'ensanch': 'ensanchamiento', 'expens': 'expansión', 'lin': 'lin', 'paravertebral': 'paravertebral',
    'escas': 'escaso', 'espiracion': 'espiración', 'torac': 'torácico', 'engros': 'engrosamiento',
    'pleuroparenquimat': 'pleuroparenquimatoso', 'biapical': 'biapical', 'hemidiafragm': 'hemidiafragma',
    'dorsal': 'dorsal', 'perd': 'pérdida', 'volum': 'volumen', 'hemitorax': 'hemitórax', 'lsd': 'lsd',
    'asoci': 'asociado', 'tract': 'tracto', 'pleural': 'pleural', 'secuel': 'secuela', 'tbc': 'tbc',
    'elevacion': 'elevación', '29': '29', '01': '01', '2017': '2017', 'comp': 'complicación',
    'rot': 'rotación', 'entid': 'entidad', 'escapul': 'escápula', 'visibl': 'visible', '2012': '2012',
    'pued': 'puede', 'trat': 'tratamiento', 'posicional': 'posicional', 'pod': 'pod', 'descart': 'descartar',
    'caus': 'causa', 'import': 'importante', 'bronquiectasi': 'bronquiectasias', 'infrahiliar': 'infrahiliar',
    'bilateral': 'bilateral', 'calcific': 'calcificado', 'unicameral': 'unicameral', 'region': 'región',
    'pectoral': 'pectoral', 'cerclaj': 'cerclaje', 'esternotomi': 'esternotomía', 'medi': 'medio',
    'enfisem': 'enfisema', 'bull': 'bull', 'lsi': 'lsi', 'tram': 'tramo', 'broncovascul': 'broncovascular',
    'maner': 'manera', 'proces': 'proceso', 'infecci': 'infección', 'indic': 'indicación',
    'cardiotorac': 'cardiotorácico', 'congest': 'congestión', 'presion': 'presión', 'caj': 'caja',
    'limit': 'limitación', 'calcificacion': 'calcificación', 'ligament': 'ligamento', 'longitudinal': 'longitudinal',
    'comun': 'común', 'raquis': 'raquis', 'foresti': 'forestier', 'hiperostosis': 'hiperostosis',
    'esquelet': 'esqueleto', 'idiopat': 'idiopático', 'difus': 'difuso', 'opac': 'opacidad', 'marc': 'marcado',
    'parahiliar': 'parahiliar', 'may': 'mayor', '2016': '2016', 'basal': 'basal', 'rest': 'resto',
    'fibros': 'fibrosis', 'granulom': 'granuloma', 'apical': 'apical', 'vertic': 'vertical', 'caract': 'característica',
    'especif': 'específica', 'residual': 'residual', 'ciert': 'cierta', 'cay': 'cay', 'fractur': 'fractura',
    'clavicul': 'clavícula', 'intersticioalveol': 'intersticioalveolar', 'context': 'contexto',
    'etiologi': 'etiología', 'inflamatori': 'inflamatorio', 'espondilosis': 'espondilosis', 'visualiz': 'visualización',
    'camp': 'campo', 'masa': 'masa', 'aproxim': 'aproximadamente', '5': '5', 'x': 'x', '6': '6', '4': '4', 'cm': 'cm',
    'bien': 'bien', 'defin': 'definido', 'rx': 'rx', 'fech': 'fecha', '25': '25', '09': '09', '2013': '2013',
    'primer': 'primer', 'posibil': 'posibilidad', 'diagnost': 'diagnóstico', 'tumoral': 'tumoral', 'introduc': 'introducción',
    'circuit': 'circuito', 'intern': 'interno', 'tumor': 'tumor', 'cit': 'cit', 'form': 'forma', 'urgent': 'urgente',
    'realizacion': 'realización', 'tc': 'tc', 'sutur': 'sutura', 'bicameral': 'bicameral', 'electrod': 'electrodo',
    'ad': 'ad', 'vd': 'vd', 'motiv': 'motivo', 'consult': 'consulta', 'dolor': 'dolor', 'cost': 'costal', 'izdo': 'izquierdo',
    'significaion': 'significación', 'melanom': 'melanoma', 'esplda': 'espalda', 'anodin': 'anodino', 'parec': 'parece',
    'extrapleural': 'extrapleural', 'call': 'call', 'osea': 'ósea', 'fals': 'falsa', 'imag': 'imagen', 'nivel': 'nivel',
    'complet': 'completo', 'cifoescoliosis': 'cifoescoliosis', 'objetiv': 'objetivo', '08': '08', '2011': '2011',
    'si': 'si', 'compat': 'compatible', 'neumon': 'neumonía', 'osteosintesis': 'osteosíntesis', 'nodul': 'nódulo', 'hipertrofi': 'hipertrofia',
    'articulacion': 'articulación', 'costill': 'costilla', 'esternon': 'esternón', 'cardiac': 'cardíaco',
    'alto': 'alto', 'observ': 'observación', 'consolid': 'consolidación', 'inspir': 'inspiratorio',
    'tenu': 'tenue', 'infrahili': 'infrahiliar', 'poc': 'poco', 'inspiracion': 'inspiración',
    'valor': 'valor', 'funcion': 'función', 'exploracion': 'exploración', 'aort': 'aorta', 'laminar': 'laminar',
    'inferior': 'inferior', 'identif': 'identificar', 'present': 'presente', 'impos': 'imposible',
    '23': '23', '12': '12', 'contorn': 'contorno', 'caracterist': 'característica', 'evident': 'evidente',
    'derram': 'derrame', 'conserv': 'conservado', 'vascularizacion': 'vascularización', 'plan': 'plan',
    'inclu': 'incluir', 'subsegmentari': 'subsegmentaria', 'consolidacion': 'consolidación', 'lid': 'límite',
    'hiliar': 'hiliar', 'lobul': 'lobular', 'lad': 'lado', 'deform': 'deformidad', 'arco': 'arco',
    'costal': 'costal', 'noven': 'noveno', 'paquipleuritis': 'paquipleuritis', '2010': '2010',
    'correspond': 'corresponde', 'mamil': 'mamilar', 'pers': 'personal', 'unic': 'único', 'zon': 'zona',
    'secundari': 'secundaria', 'cirugi': 'cirugía', 'hil': 'hilo', 'patologi': 'patológica', 'parenquimat': 'parenquimatoso',
    'subyacent': 'subyacente', 'sospech': 'sospecha', 'union': 'unión', 'terci': 'tercio', 'extern': 'externo',
    'hipertension': 'hipertensión', 'vasculopulmon': 'vasculopulmonar', 'ocupacion': 'ocupación',
    'espaci': 'espacio', 'alveol': 'alveolar', 'embarg': 'embargo', 'predomini': 'predomina', '04': '04',
    '02': '02', 'tac': 'TAC', 'osteopeni': 'osteopenia', 'acord': 'acorde', 'impid': 'impide',
    'valoracion': 'valoración', 'adecu': 'adecuado', 'osificacion': 'osificación', 'part': 'parte',
    'bland': 'blando', 'puent': 'puente', 'vi': 'vía', 'aorticasin': 'aórticas sin', 'dobl': 'doble',
    'curv': 'curva', 'pinzamient': 'pinzamiento', 'ict': 'ICT', 'segment': 'segmento', 'medial': 'medial',
    'lmd': 'LMD', 'alveolointersticial': 'alveolointersticial', 'paracardiac': 'paracardiaco',
    'ginecomasti': 'ginecomastia', 'existent': 'existente', 'cavitacion': 'cavitación', 'suprahili': 'suprahiliar',
    'ser': 'ser', 'ct': 'CT', 'program': 'programa', 'patron': 'patrón', 'intersticial': 'intersticial',
    'neumoni': 'neumonía', 'atip': 'atípico', 'bronqui': 'bronquial', 'boton': 'botón', 'v': 'v',
    'd': 'D', 'segun': 'según', 'histori': 'historia', 'obstant': 'no obstante', 'aconsej': 'aconsejado',
    'control': 'control', 'tras': 'tras', 'tratamient': 'tratamiento', 'cervical': 'cervical', 'variant': 'variante',
    '20': '20', '10': '10', 'salv': 'salvamento', 'retroesternal': 'retroesternal',
    'hiperinsuflacion': 'hiperinsuflación', '6o': '6º', 'suci': 'SUCI', 'condensacion': 'condensación',
    'finaliz': 'finalizado', 'resolucion': 'resolución', 'are': 'área', 'paratraqueal': 'paratraqueal',
    'noviembr': 'noviembre', 'extens': 'extenso', 'neces': 'necesario', 'encalv': 'encalvamiento',
    'endomedul': 'endomedular', 'mas': 'más', 'grand': 'grande', 'fin': 'fin', 'consider': 'considerado',
    'dai': 'DAI', 'lamin': 'laminar', 'persist': 'persistente', 'variacion': 'variación', 'practic': 'práctica',
    'seudonodul': 'seudonódulo', 'mal': 'mal', 'delimit': 'delimitado', 'octubr': 'octubre', '2014': '2014',
    'acig': 'ACIG', 'aspect': 'aspecto', '28': '28', '03': '03', 'seman': 'semana', 'finalizacion': 'finalización',
    'empeor': 'empeoramiento', '30': '30', '05': '05', 'actual': 'actual', 'afect': 'afectado',
    'tumoracion': 'tumoración', 'arcos': 'arcos', 'plac': 'placa', 'abril': 'abril', 'pes': 'peso',
    'diferent': 'diferente', 'tecnic': 'técnica', 'ls': 'LS', 'micronodul': 'micronódulo', 'adenopati': 'adenopatía',
    'neoplasi': 'neoplasia', 'podri': 'podría', 'marcaj': 'marcaje', '24': '24', 'marz': 'marzo', '2015': '2015',
    'micronodular': 'micronodular', 'permanec': 'permanece', 'haci': 'haciendo', 'lingul': 'lingular',
    'elong': 'elongación', 'disposit': 'dispositivo', 'subcutane': 'subcutáneo', 'evidenci': 'evidencia',
    'tos': 'tos', 'expectoracion': 'expectoración', 'mes': 'mes', 'paremquim': 'parénquima', 'ecograf': 'ecografía',
    'convex': 'convexo', 'antigu': 'antiguo', 'etc': 'etc.', 'discoartopati': 'discoartropatía', 'tapon': 'tapón',
    'moc': 'moco', '18': '18', 'nuev': 'nuevo', 'aparicion': 'aparición', 'mejor': 'mejor', 'contraindiqu': 'contraindicado',
    'punt': 'punto', 'vist': 'vista', 'resen': 'resen', 'radiografi': 'radiografía', 'simpl': 'simple',
    'abdom': 'abdominal', 'impresion': 'impresión', 'intersomat': 'intersomático', 'l2': 'L2', 'l3': 'L3',
    'l4': 'L4', 'l5': 'L5', 's1': 'S1', 'luminogram': 'luminograma', 'obstruccion': 'obstrucción',
    'intestinal': 'intestinal', 'intersticioalveolar': 'intersticioalveolar', 'perihiliar': 'perihiliar',
    'asi': 'así', 'platill': 'platillo', '7o': '7º', 'cuerp': 'cuerpo', 'fijacion': 'fijación',
    'peribronquial': 'peribronquial', 'tabaqu': 'tabaquismo', 'borr': 'borrar', 'parcial': 'parcial',
    'bord': 'bordes', 'conoc': 'conocido', 'compens': 'compensado', 'costofriafragmat': 'costofriafrenático',
    'acumul': 'acumulado', 'gras': 'grasa', 'cardiofren': 'cardiofrénico', 'ano': 'ano', 'protesis': 'prótesis',
    'mamari': 'mamaria', 'establ': 'establecido', 'realiz': 'realizado', 'entra': 'entrada', 'reconoc': 'reconocido',
    'costodiafragmat': 'costodiafragmático', 'quist': 'quistico', 'hidatid': 'hidatídico', 'hepat': 'hepático',
    'nodular': 'nodular', 'angul': 'angular', 'permeabl': 'permeable', 'tres': 'tres', '13': '13', 'densidad': 'densidad',
    'pseudonodular': 'pseudonodular', 'compar': 'comparación', 'diafragmat': 'diafragmático', '19': '19',
    'juli': 'julio', 'mayor': 'mayor', 'material': 'material', 'vertebr': 'vertebral', 'lumbar': 'lumbar',
    'reservori': 'reservorio', 'esternal': 'esternal', 'lev': 'levantamiento', 'altos': 'altos', 'anill': 'anillo',
    'mitral': 'mitral', 'primari': 'primario', 'mesoteliom': 'mesotelioma', 'neoplas': 'neoplásica',
    'dimension': 'dimensión', 'realic': 'realice', 'coleccion': 'colección', 'locul': 'loculado',
    'habr': 'habrá', 'tip': 'tipo', 'dudos': 'dudoso', 'situacion': 'situación', 'recomend': 'recomendación',
    'desaparicion': 'desaparición', 'psuedonodul': 'pseudonódulo', 'superpuest': 'superpuesto',
    'proyeccion': 'proyección', 'lordot': 'lordosis', '8o': '8º', 'recom': 'recomendación', 'perifer': 'periférico',
    'morfologi': 'morfológica', 'ampli': 'amplia', 'pleur': 'pleural', 'cuadr': 'cuadrante', 'evolucion': 'evolución',
    'infra': 'infra', 'parrill': 'parrilla', 'dos': 'dos', '8a': '8ª', '9a': '9ª', 'multipl': 'múltiple',
    'perihili': 'perihiliar', 'foc': 'foco', 'pectus': 'pectus', 'carinatum': 'carinatum', '21': '21', 'lm': 'lm',
    'aunqu': 'aunque', 'component': 'componente', 'subacromial': 'subacromial', 'traduc': 'traducción',
    'rotur': 'rotura', 'manguit': 'manguito', 'rotador': 'rotador', 'agu': 'aguja', 'cisural': 'cisural',
    'aspiracion': 'aspiración', 'casi': 'casi', 'ahog': 'ahogo', 'dispon': 'disponibilidad', 'cavum': 'cavum',
    'rinofaring': 'rinofaringe', 'adenoid': 'adenoides', 'piel': 'piel', 'l': 'l', 'osteoporosis': 'osteoporosis',
    'aplast': 'aplastamiento', 'd11': 'D11', 'enfisemat': 'enfisematoso', 'osteoblast': 'osteoblasto',
    'cuel': 'cuello', 'metastasis': 'metástasis', 'portacath': 'portacath', 'comparacion': 'comparación',
    '07': '07', '16': '16', 'disminucion': 'disminución', 'edem': 'edema', 'clar': 'claridad', 'dens': 'densidad',
    'ocup': 'ocupación', 'pleuropericard': 'pleuropericárdico',  'opcion': 'opción', 'grap': 'grapa', 'huec': 'hueco', 'axil': 'axila', 'cardicac': 'cardíaca',
    'alta': 'alta', 'modific': 'modificación', 'crec': 'crecimiento', 'minim': 'mínimo', 'pinz': 'pinza',
    'elongracion': 'elongación', 'mam': 'mama', 'izqueird': 'izquierda', 'solitari': 'solitario',
    'hac': 'hace', 'anos': 'años', 'mid': 'medio', '2': '2', '66': '66', 'cms': 'cms', 'eje': 'eje',
    'transvers': 'transversal', 'izda': 'izquierda', 'ambbas': 'ambas', 'art': 'artículo',
    'glenohumeral': 'glenohumeral', 'cateter': 'catéter', 'auscultacion': 'auscultación',
    'horizontalizacion': 'horizontalización', 'global': 'global', 'grad': 'graduación',
    'redistribucion': 'redistribución', 'fall': 'falla', 'metastasectomi': 'metastasectomía',
    'sutut': 'sutura', 'kii': 'kii', 'mastectomi': 'mastectomía', 'alveolar': 'alveolar',
    'recomiend': 'recomienda', '3': '3', 'termin': 'término', 'llam': 'llamada', 'atencion': 'atención',
    'pericarditis': 'pericarditis', 'pericard': 'pericardio', 'hipercifosis': 'hipercifosis',
    'sensacion': 'sensación', 'falt': 'falta', 'air': 'aire', 'dendisd': 'densidad',
    'correspondent': 'correspondiente', 'segmentari': 'segmentaria', 'ascens': 'ascenso',
    '17': '17', 'afectacion': 'afectación', 'vecind': 'vecindad', 'ipsilateral': 'ipsilateral',
    'dich': 'dicho', 'antecedent': 'antecedente', 'cre': 'crea', 'habri': 'habría', 'altern': 'alternativa',
    'infeccion': 'infección', 'tubercul': 'tuberculosa', 'neumonectomi': 'neumonectomía',
    'cicatricial': 'cicatricial', '06': '06', 'artefact': 'artefacto', 'ambas': 'ambas', 'calci': 'calcificación',
    'osteolisis': 'osteolisis', 'adyacent': 'adyacente', 'sext': 'sexta', 'posterolateral': 'posterolateral',
    'segund': 'segundo', 'parahili': 'parahiliar', 'carcinom': 'carcinoma', 'neumologi': 'neumología',
    'inform': 'informe', 'medic': 'médico', 'peticionari': 'peticionario', 'subcentimetr': 'subcentimétrico',
    'gran': 'gran', 'acompan': 'acompañamiento', 'desviacion': 'desviación', 'suger': 'sugerencia',
    'igual': 'igual', 'algun': 'alguno', 'dad': 'dad', 'congenit': 'congénito', 'bronquialveol': 'bronquialveolar',
    'siend': 'siendo', 'imprescind': 'imprescindible', 'pa': 'para', 'significi': 'significado',
    'oval': 'oval', 'altur': 'altura', 'aplan': 'aplanamiento', 'ello': 'ello', 'aport': 'aporte',
    'obes': 'obesidad', 'unidad': 'unidad', 'disc': 'disco', 'exposicion': 'exposición', 'abest': 'abestinencia',
    'cavidad': 'cavidad', 'ateromat': 'ateromatosis', 'hundimient': 'hundimiento', 'd9': 'd9',
    'l1': 'l1', 'diagragmat': 'diafragma', 'rodill': 'rodilla', 'alineacion': 'alineación',
    'suboptim': 'subóptimo', 'deb': 'debajo', 'inclusion': 'inclusión', 'fisiolog': 'fisiológico',
    'inmovilizacion': 'inmovilización', 'cifoscoliosis': 'cifoscoliosis', 'queimpiod': 'queimpiod',
    'salved': 'salvedad', 'interstici': 'intersticial', 'hipocondri': 'hipocondrio', 'timic': 'tímico',
    'peribroncovascul': 'peribroncovascular', 'signo': 'signo', 'osteofit': 'osteofito', 'moder': 'moderado',
    'cantid': 'cantidad', 'post': 'posterior', 'atrav': 'atravesando', 'electr': 'electro', 'costrofren': 'costrofrénico',
    'paraaort': 'paraaórtico', 'contact': 'contacto', 'asbest': 'asbesto', 'despeg': 'despegado',
    'bilobul': 'bilobulado', 'contr': 'contraste', 'eongacion': 'elongación', 'traz': 'trazo',
    'seis': 'seis', 'apendic': 'apéndice', 'xifoid': 'xifoides', 'sobretod': 'sobretodo', '1': '1',
    'seri': 'serie', 'correct': 'correcto', 'fumador': 'fumador', 'dosal': 'dorsal', 'concav': 'cóncavo', 'vcs': 'vcs', 'endoprotesis': 'endoprótesis',
    'line': 'linea', 'tec': 'técnica', 'broncogram': 'broncograma', 'intestici': 'intestinal', 'posttrat': 'post-tratamiento',
    'comprob': 'comprobación', 'engrosami': 'engrosamiento', 'ento': 'entorno', 'pectum': 'pectus', 'excavatum': 'excavatum',
    '5o': '5º', 'espondiloartrosis': 'espondiloartrosis', 'estenotomi': 'estenotomía', 'sensor': 'sensor', 'ventricul': 'ventricular',
    'valvul': 'valvular', 'protes': 'prótesis', 'cromic': 'cromático', '8mm': '8mm', 'clacific': 'clasificación', '27': '27',
    'angulacion': 'angulación', 'apofisis': 'apófisis', 'refuerz': 'refuerzo', 'dcha': 'derecha', 'tornill': 'tornillo', 'tortax': 'torax',
    'sec': 'secuencia', 'em': 'electromagnético', 'atrapameint': 'atrapamiento', 'insuficient': 'insuficiencia', 'quirurg': 'quirúrgico',
    'subcutan': 'subcutáneo', 'super': 'superior', 'escolisosis': 'escoliosis', 'dorsolumbr': 'dorsolumbar', 'not': 'nota',
    'escoliot': 'escoliosis', 'superpsoisicion': 'superposición', 'ausenci': 'ausencia', '2o': '2º', 'subcapital': 'subcapital',
    'viualiz': 'visualización', 'esclerosis': 'esclerosis', 'curvatur': 'curvatura', 'asimetri': 'asimetría', 'desplaz': 'desplazamiento',
    'traqueal': 'traqueal', 'impront': 'impresión', 'tiroide': 'tiroides', 'dias': 'días', 'complic': 'complicación',
    'ateormatosis': 'ateromatosis', 'lipomatosis': 'lipomatosis', 'catarr': 'catarro', 'tambi': 'también', 'alteracion': 'alteración',
    'ventan': 'ventana', 'aortopulmon': 'aortopulmonar', 'septim': 'septum', 'inespecif': 'inespecífico', 'lineal': 'lineal',
    'subcentrimetr': 'subcentimétrico', 'bronquitis': 'bronquitis', 'repeticion': 'repetición', 'fibroadenom': 'fibroadenoma',
    'alongacion': 'elongación', 'fundamental': 'fundamental', 'sintesis': 'síntesis', 'humer': 'húmero', 'discretr': 'discreto',
    'reticulonodul': 'reticulonodular',  'parch': 'parche', 'colocacion': 'colocación', 'complicacion': 'complicación', 'distribucion': 'distribución',
    'recient': 'reciente', 'plant': 'planta', 'men': 'menos', 'subpulmon': 'subpulmonar', 'vertient': 'vertiente',
    'varicel': 'varicela', 'veo': 'veo', 'ninghun': 'ningún', 'ener': 'enero', 'hombr': 'hombro', 'pulg': 'pulgar',
    'refluj': 'reflujo', 'presenci': 'presencia', 'atravies': 'atraviesa', 'cortical': 'cortical', 'fisur': 'fisura',
    'ganglion': 'ganglion', 'radiograf': 'radiografía', 'terminacion': 'terminación', 'viric': 'vírico',
    'dialisis': 'diálisis', 'panalizacion': 'panalización', 'bloqu': 'bloqueo', 'ram': 'ramificación',
    'ardiolog': 'cardiológico', 'significativs': 'significativos', 'seudonodular': 'seudonodular', '3o': '3º',
    'prevertebral': 'prevertebral', 'd3': 'D3', 'posteroanterior': 'posteroanterior', 'repet': 'repetición',
    'pezon': 'pezón', 'd6': 'D6', 'd7': 'D7', 'remanent': 'remanente', 'leucocitosis': 'leucocitosis',
    'apic': 'apical', 'ap': 'aproximadamente', 'oblicu': 'oblicuo', '26': '26', '7': '7', 'antibiot': 'antibiótico',
    'mism': 'mismo', 'ic': 'cardíaco', 'retraccion': 'retracción', 'arrib': 'arriba', 'enclav': 'enclavado',
    'textur': 'textura', 'traumat': 'traumatismo', 'u': 'último', 'paget': 'Paget', 'agud': 'agudo', 'regl': 'regla',
    'recuerd': 'recuerdo', 'bambu': 'bambú', 'espondilitis': 'espondilitis', 'anquilopoyet': 'anquilopoyético',
    'hiperair': 'hiperinsuflación', 'reticul': 'reticular', 'factor': 'factor', 'riesg': 'riesgo', 'alarg': 'alargamiento',
    'atribu': 'atribuible', 'radioterapi': 'radioterapia', 'sug': 'sugerencia', 'baj': 'bajo', 'aprox': 'aproximado',
    'islot': 'islote', 'disne': 'disnea', 'condes': 'condensación', 'ambulatori': 'ambulatorio',
    'enferemd': 'enfermedad', 'alevol': 'a nivel', 'intesticial': 'intersticial', 'disfuncion': 'disfunción',
    'paramediastin': 'paramediastinal', 'proxim': 'próximo', 'costoesternal': 'costoesternal', 'rang': 'rango',
    'cartilag': 'cartílago', 'clips': 'clips', 'postcolecistectomi': 'postcolecistectomía', 'iv': 'intravenoso',
    'diciembr': 'diciembre', 'incipient': 'incipiente', 'reduc': 'reducción',
    'gangli': 'ganglio', 'subpleural': 'subpleural', 'hal': 'hallazgo', 'radiotransparent': 'radiotransparente',
    'casual': 'casual', 'cuart': 'cuarto', '4mm': '4 mm', 'micronodualr': 'micronodular', 'distrbucion': 'distribución',
    'conqu': 'conque', 'prim': 'primera', 'bronquial': 'bronquial', 'sol': 'solución', 'rueg': 'ruego',
    'remit': 'remite', 'ray': 'rayos', 'pizamient': 'pizamiento', 'exam': 'examen', 'fisic': 'físico', 'icc': 'ICC',
    'col': 'col', 'deslust': 'deslustre', 'canul': 'cánula', 'traqueotomi': 'traqueotomía', 'hemidiafragmat': 'hemidiafragmático',
    'dchas': 'derechas', 'puntiform': 'puntiforme', 'modif': 'modificación', 'valvular': 'valvular', 'versus': 'versus',
    'lobectomi': 'lobectomía', 'costofrenci': 'costofrénico', 'equipar': 'equiparar', 'visauliz': 'visualizar',
    'encuentr': 'encuentra', 'logr': 'lograr', 'sombr': 'sombra', 'sumacion': 'sumación', 'd8': 'D8',
    'generaliz': 'generalizada', 'infriltr': 'infiltración', 'agrup': 'agrupación', 'cupul': 'cúpula',
    'colecistectomi': 'colecistectomía', 'espondiloartropati': 'espondiloartropatía', 'cisur': 'cisura',
    'osteopororsis': 'osteoporosis', 'junt': 'junto', 'pues': 'pues', 'vas': 'vas', 'ortogonal': 'ortogonal',
    'evalu': 'evaluación', 'hidroneumotorax': 'hidroneumotórax', 'dist': 'distancia', 'doceav': 'doceava',
    'inclusiv': 'inclusiva', 'supraclavicul': 'supraclavicular', 'pleuroapical': 'pleuroapical',
    'aretrocardiac': 'retrocardíaco', 'pinzaminet': 'pinzamiento', 'fal': 'falda', '9o': '9º', 'abomb': 'abombamiento',
    'pleuroacigoesofag': 'pleuroacigosofágico', 'transicion': 'transición', 'toracoabdominal': 'toracoabdominal',
    'varic': 'varices', 'esofag': 'esófago', 'caridotorac': 'cardiotórax', 'diametr': 'diámetro', 'maxim': 'máximo',
    'imprecis': 'impreciso', 'mm': 'mm', 'cad': 'cad', 'intratorac': 'intratorácica', '215': '215',
    'radioopac': 'radioopaco', 'mantoux': 'Mantoux', 'intui': 'intuir', 'biconvex': 'biconvexo', '4o': '4º',
    'inspiratori': 'inspiratorio', 'quistic': 'quístico', 'cavit': 'cavidad', 'comunic': 'comunicación',
    'telefon': 'teléfono', 'centr': 'central', 'salud': 'salud', 'correspondient': 'correspondiente', 'apex': 'ápex',
    'borramient': 'borramiento', 'aireacion': 'aireación', 'determi': 'determinación', 'atenuacion': 'atenuación',
    'silicosis': 'silicosis', 'rod': 'rodilla', 'principal': 'principal', 'cuy': 'cuya', 'rotacion': 'rotación',
    'sarcoidosis': 'sarcoidosis', 'subcondral': 'subcondral', 'acromion': 'acromion', 'muscul': 'muscular',
    'sobreinfeccion': 'sobreinfección', 'disminu': 'disminución', 'esqulet': 'esqueleto', 'inlcu': 'incluye',
    'total': 'total', 'hiperdens': 'hiperdensa', 'costocondral': 'costocondral', 'primoinfeccion': 'primoinfección',
    'hiperinsufl': 'hiperinsuflación', 'pobrement': 'pobremente', 'desflec': 'desflecado',
    'revascularizacion': 'revascularización', 'coronari': 'coronaria', 'adelgaz': 'adelgazamiento', 'ten': 'ten',
    'radiologi': 'radiológica', 'retencion': 'retención', 'secrecion': 'secreción', 'senocostofren': 'senocostofrénica',
    'b': 'b', 'kerly': 'Kerly', 'cervic': 'cervical', 'tod': 'todo', 'exces': 'exceso', 'penetr': 'penetración',
    'condici': 'condición', 'do': 'do', 'afil': 'afilado', 'holt': 'Holt', 'desconoc': 'desconocido',
    'coincid': 'coincide', '2008': '2008', 'pumon': 'pulmón', 'dign': 'dignidad', 'obliteracion': 'obliteración',
    'costodiafrgmat': 'costodiafragmático', 'posteri': 'posterior', 'posibl': 'posible', 'portador': 'portador',
    'colaps': 'colapsa', 'nediastin': 'mediastino', 'perihil': 'perihilár', 'bibasl': 'bibasilar', 'quint': 'quinta',
    'sub': 'sub', 'acromial': 'acromial', 'bronc': 'bronco', 'intersicial': 'intersticial', 'izdas': 'izquierdas',
    'cardiototac': 'cardiotórax', 'pulmoar': 'pulmonar', 'saos': 'SAOS', 'realment': 'realmente', 'sab': 'saber',
    'esudi': 'estudio', 'morfolog': 'morfológica', 'c': 'c', 'pleuroparenquimato': 'pleuroparenquimatoso',
    'refier': 'refiere', 'cansanci': 'cansancio', 'confirm': 'confirmación', 'element': 'elemento',
    'anteriorers': 'anteriores', 'postradioterapi': 'postradioterapia', 'p': 'p', 'rdid': 'ridículo',
    'prominenent': 'prominente', 'implant': 'implante', 'fisis': 'fisis', 'agost': 'agosto', 'epipericarci': 'epipericárdico',
    'ocu': 'ocurrido', 'paton': 'patrón', 'muestr': 'muestra', 'infeci': 'infección', 'radic': 'radiculopatía',
    'marcaps': 'marcapasos', 'endocavitari': 'endocavitaria', 'activacion': 'activación', 'grumos': 'grumos',
    '15x5': '15x5', 'porcion': 'porción', 'superointern': 'superointerno', 'irregul': 'irregular', 'diafisis': 'diáfisis',
    'corresponderi': 'correspondería', 'posicion': 'posición', 'linfangitis': 'linfangitis', 'conclusion': 'conclusión',
    'carcinomat': 'carcinomatoso', 'radiolucent': 'radiolúcido', 'confluyent': 'confluyente', '8': '8', 'ala': 'ala',
    'ariculacion': 'articulación', 'estern': 'esternón', 'apar': 'aparición', 'laboral': 'laboral',
    'enrelacion': 'en relación', 'ded': 'dedo', 'articul': 'articulación', 'glen': 'glenoideo', 'tej': 'tejido',
    'hiatal': 'hiatal', 'paraesofag': 'paraesofágico', 'mixt': 'mixto', 'mcp': 'MCP', 'situ': 'situación',
    'infraclavicul': 'infraclavicular', '5cm': '5 cm', 'superposicion': 'superposición', 'vari': 'variante',
    'persistent': 'persistente', 'blanc': 'blanco', 't12': 'T12', 'compl': 'completa', '4cm': '4 cm', 'crecimient': 'crecimiento',
    'lepid': 'lepidico', 'osteoporot': 'osteoporótica', 'presneci': 'presencia', 'perhiliar': 'perihilar', '1o': '1º', 'deposit': 'depósito',
    '11o': '11º', 'habit': 'habitación', 'constitucional': 'constitucional', 'fiebr': 'fiebre', 'izdos': 'izquierdos',
    'cardiacol': 'cardíaco', 'descompens': 'descompensación', 'paranasal': 'paranasal', 'neumatiz': 'neumatización',
    'pleruparenquimat': 'pleuroparenquimatoso', 'd10': 'D10', 'drenaj': 'drenaje', 'ventriculoperitoneal': 'ventriculoperitoneal',
    'carinal': 'carinal', 'resuelt': 'resuelto', 'biopsi': 'biopsia', 'hiperlordot': 'hiperlordótica', 'solicit': 'solicitó',
    'degenr': 'degeneración', 'esta': 'está', 'aer': 'aérea', 'quesu': 'queso', 'gier': 'gigante', 'extran': 'extranjero',
    'neumocistis': 'neumocistis', 'mesogastri': 'mesogástrico', 'crane': 'craneal', 'caudal': 'caudal', 'caracteriz': 'caracteriza',
    'calfic': 'calcificación', 'cuent': 'cuenta', 'caracterizacion': 'caracterización', 'interior': 'interior', 'torp': 'torpe',
    'oblig': 'obligación', 'adenocarcinom': 'adenocarcinoma', 'calid': 'calidad', 'aostic': 'aórtico', 'derecch': 'derecha',
    'masas': 'masas', 'orejuel': 'orejuela', 'ca': 'caso', 'prostat': 'prostático', 'insterstici': 'intersticial',
    'radioolog': 'radiológica', 'descompensacion': 'descompensación', 'situs': 'situs', 'inversus': 'inversus',
    'dextrocardi': 'dextrocardia', 'dispong': 'disponga', 'verdader': 'verdadero', 'probabal': 'probable', '3mm': '3 mm',
    'renal': 'renal', 'pelvic': 'pélvico', 'anquilosis': 'anquilosis', 'cronologi': 'cronológica', 'excepcion': 'excepción',
    'izqda': 'izquierda', 'paraort': 'paraórtico', 'infilt': 'infiltrado', 'endotorac': 'endotorácico', 'ecografi': 'ecografía',
    'similar': 'similar', '016': '016', 'sangr': 'sangre', 'reinsercion': 'reinserción', 'tendin': 'tendón', 'parical': 'parcial',
    'cruc': 'cruce', 'relacioncon': 'relación con', 'despu': 'después', 'pas': 'paso', 'diez': 'diez', 'necrosis': 'necrosis',
    'avascul': 'avascular', 'epigastri': 'epigástrico', 'respet': 'respeto', 'prctic': 'práctica', 'gas': 'gas', 'chilaiditi': 'Chilaiditi',
    'infiltracion': 'infiltración', 'establec': 'estableció', 'incidental': 'incidental', 'agres': 'agresivo', 'seud': 'seudónimo',
    'retrohemidiafragmat': 'retrohemidiafragmático', 'incurvacion': 'incurvación', 'sid': 'SID', 'intrapulmon': 'intrapulmonar',
    'evolut': 'evolución', 'impactacion': 'impactación', 'mucos': 'mucosa', 'tox': 'tóxica', 'justific': 'justificación',
    'prueb': 'prueba', 'rotacional': 'rotacional', 'pedicul': 'pedículo', 'opacidadd': 'opacidad', 'intra': 'intra',
    'varon': 'varón', '80': '80', 'min': 'minutos', 'esfuerz': 'esfuerzo', 'paut': 'pauta', 'medicacion': 'medicación',
    'exacerbacion': 'exacerbación', 'auscultatori': 'auscultatorio', 'buen': 'buen', 'saturacion': 'saturación',
    'oxigen': 'oxígeno', 'miembr': 'miembro', 'apicoposterior': 'apicoposterior', 'cuanti': 'cuantitativa',
    'explor': 'exploración', 'complementari': 'complementaria', 'lis': 'líquido', 'hidroaere': 'hidroaérea',
    'maxilar': 'maxilar', 'frontal': 'frontal', 'pud': 'puede', 'sinusitis': 'sinusitis', 'calibr': 'calibrar',
    'estrict': 'estrictura', 'triangul': 'triangular', 'diferencial': 'diferencial', 'plante': 'plantea',
    'combinacion': 'combinación', 'traqueostomi': 'traqueostomía', 'elev': 'elevación', 'interposicion': 'interposición',
    'asas': 'asas', 'superfici': 'superficie', 'rectificacion': 'rectificación', 'camb': 'cambio',
    'acus': 'acusis', 'depresion': 'depresión', 'neumonitis': 'neumonitis', 'ocasion': 'ocasión', 'pseud': 'pseudo',
    'd12': 'D12', 'engrosmient': 'engrosamiento', 'criteri': 'criterio', 'benign': 'benigna', 'sal': 'sal', 'aneurismat': 'aneurismática',
    'l11': 'L11', 'l12': 'L12', 'mediastino': 'mediastino', 'opaciad': 'opacidad', 'obtant': 'obtante', 'correl': 'correlación',
    'futur': 'futuro', 'genraliz': 'generalizada', 'siogn': 'signo', 'larg': 'largo', 'gram': 'gramo', 'extrinsec': 'extrínseco',
    'calcifc': 'calcificación', 'probablmentt': 'probablemente', 'liqu': 'líquido', '11x4': '11x4', 'topografi': 'topografía',
    'averi': 'avería', 'pacs': 'pacs', 'cotej': 'cotejo', 'asbestosis': 'asbestosis', 'densiid': 'densidad', 'den': 'denso',
    'febril': 'febril', 'sihn': 'signo', 'totax': 'total', 'expans': 'expansión', 'band': 'banda', 'dar': 'dar', 'ver': 'ver',
    'suprahiliar': 'suprahilar', 'atelectas': 'atelectasia', 'aelectasi': 'atelectasia', 'broncopati': 'broncopatía',
    'traqueobronquial': 'traqueobronquial', 'unipol': 'unipolar', 'conic': 'cónico', '2004': '2004', 'f': 'forma', 'acambi': 'cambio',
    's': 'sí', 'epareci': 'pareció', 'viriasis': 'viremia', 'aterom': 'ateroma', 'derrram': 'derrame', 'inlfamatori': 'inflamatorio',
    'radiopac': 'radiopaco', '3cm': '3 cm', '7mm': '7 mm', 'asimetr': 'asimetría', 'descedent': 'descendente', '12o': '12º',
    'dcho': 'derecho', 'interpret': 'interpretación', 't10': 'T10', 't11': 'T11', 'mestastas': 'metástasis', 't': 'total',
    'orax': 'órax', 'sond': 'sonda', 'nasogastr': 'nasogástrica', 'infradiafragmat': 'infradiafragmático', 'predomin': 'predominio',
    'septiembr': 'septiembre', 've': 'vértice', 'superpon': 'superponer', '31': '31', 'exput': 'esputo', 'hemopt': 'hemoptisis',
    'definicion': 'definición', 'implantacion': 'implantación', 'osteotomi': 'osteotomía', 'naturalez': 'naturaleza',
    'recidual': 'residual', 'produc': 'producción', 'clics': 'clics', 'frenic': 'frénico', 'sing': 'signo',
    'deficient': 'deficiente', 'instersticial': 'intersticial', 'formacion': 'formación', 'osteofitari': 'osteofitaria',
    'caraact': 'característica', 'radioog': 'radiografía', 'pleuropulmonar': 'pleuropulmonar', 'displasi': 'displasia',
    'metafisis': 'metáfisis', 'infart': 'infarto', 'justiofiqu': 'justifique', 'clip': 'clip', 'exacavatum': 'excavatum',
    'conform': 'conformación', 'retroestarnal': 'retroesternal', 'enfermedadl': 'enfermedad', 'izo': 'izo', 'hemidiafrgam': 'hemidiafragma',
    'fusion': 'fusión', 'discal': 'discal', 'hepatodiafragmat': 'hepatodiafragmático', 'colon': 'colon', 'sdre': 'SDRE',
    'chilaiditis': 'Chilaiditis', 'tsa': 'TSA', 'alej': 'alejamiento', 'dosolumb': 'dosolumbar', 'retr': 'retiro',
    'elongaci': 'elongación', 'suparaaort': 'supraaórtica', 'cuatr': 'cuatro', 'existi': 'existir', 'artrodesis': 'artrodesis',
    'tubular': 'tubular', 'restroesternal': 'restroesternal', 'estrell': 'estrella', 'aparient': 'apariencia',
    '1015': '10-15', 'areolar': 'areolar', 'intramedul': 'intramedular', 'decid': 'deciduo', 'bipedestacion': 'bipedestación',
    'nefrectomi': 'nefrectomía', 'interstical': 'intersticial', 'isntersticial': 'intersticial', 'pleuroparenquimatosis': 'pleuroparenquimatosis',
    'cam': 'campo', 'osteocondromatosis': 'osteocondromatosis', 'sinovial': 'sinovial', '8cm': '8 cm', 'hcd': 'HCD',
    'gammagrafi': 'gammagrafía', 'q': 'que', 'g': 'g', 'ventilacion': 'ventilación', 'techneg': 'Technegas',
    'mci': 'mCi', 'crisol': 'crisol', 'homogene': 'homogénea', 'radiotraz': 'radiotracer', 'defect': 'defecto',
    'perfusion': 'perfusión', 'tc99m': 'Tc99m', 'maa': 'MAA', 'permit': 'permite', 'tep': 'TEP', 'bronconeumoni': 'bronconeumonía',
    'inflmatori': 'inflamatorio', 'cardiogen': 'cardiogénico', 'compr': 'compresión', 'biliateral': 'bilateral',
    'calcic': 'cálcico', 'llamat': 'llamativo', 'carin': 'carina', 'hemipelvis': 'hemipelvis', 'af': 'afectación',
    'visualizacion': 'visualización', '10o': '10º', 'episodi': 'episodio', 'pulmoanr': 'pulmonar',
    'nodularesmilimetr': 'nodulares milimétricos', 'bullos': 'bullosa', 'bronquietasi': 'bronquiectasias',
    'sobreinfect': 'sobreinfección', 'sng': 'SNG', 'normoposicion': 'normoposición', 'deconozc': 'desconozco',
    'neum': 'neumonía', 'transcion': 'transición', 'reemplaz': 'reemplazo', 'cif': 'CIF', 'traquebroncomalaci': 'traqueobroncomalacia',
    'kerley': 'Kerley', 'desestructuracion': 'desestructuración', 'peritoneal': 'peritoneal', 'gastric': 'gástrica',
    'entrad': 'entrada', 'metaneumon': 'metaneumonía', '72': '72', 'h': 'hora', 'linfadenectomi': 'linfadenectomía',
    'destruccion': 'destrucción', 'pend': 'pendiente', 'proced': 'procedimiento', 'quiz': 'quizás', 'aacient': 'paciente',
    'deberi': 'debería', 'ciirugi': 'cirugía', 'volv': 'volver', 'espicul': 'espícula', 'paracomplet': 'para completar',
    'algodon': 'algodón', 'semiolog': 'semiología', 'suget': 'sujeto', 'encapsul': 'encapsulación', 'prox': 'proximal',
    'luxacion': 'luxación', 'acromi': 'acromial', 'fragment': 'fragmento', 'arranc': 'arrancamiento',
    'sinhalalzg': 'sin hallazgo', 'desprov': 'desprovisto', 'cali': 'calibre', 'poodri': 'podría', 'fatig': 'fatiga',
    'plaur': 'placa', 'cal': 'calcificación', 'util': 'útil', 'mp': 'médico', 'eecc': 'extremidades superiores',
    'radilog': 'radiología', '5mm': '5 mm', 'esclerot': 'esclerosis', 'asusent': 'ausente', 'carcacterist': 'característica',
    'extiend': 'extiende', 'noc': 'noche', 'perobroncovascul': 'peribroncovascular', 'lipom': 'lipoma',
    'psedonodul': 'seudonódulo', 'intim': 'íntima', 'elongancion': 'elongación', 'propabl': 'probable',
    'product': 'producto', 'roncus': 'roncus', 'disemin': 'diseminación', 'deslsutr': 'resultados',
    'interf': 'interfaz', 'neumomediastin': 'neumomediastino', 'oteosintesis': 'osteosíntesis',
    'calficicacion': 'calcificación', 'reevalu': 'reevaluación', 'seccion': 'sección', 'intersticioaveol': 'intersticioalveolar',
    'izq': 'izquierda', 'peri': 'peritoneal', 'biconcav': 'biconcavo', 'persistend': 'persistente',
    'porces': 'proceso', 'broncoaspiracion': 'broncoaspiración', 'tcs': 'TCs', 'reactiv': 'reactivo',
    'eimagen': 'imagen', 'considereis': 'consideréis', 'protusion': 'protusión', 'estomag': 'estómago',
    'postfractur': 'postfractura', 'prodri': 'podría', 'inflmaroti': 'inflamatorio', 'verific': 'verificar',
    'clinc': 'clínica', 'retroacrad': 'retrocardíaco', 'ocn': 'con', 'aoer': 'aéreo', 'studfi': 'estudio',
    'pvisualiz': 'visualización', 'cambiops': 'cambios', 'etrocardiac': 'retrocardíaco', 'inmunodeprim': 'inmunodeprimido',
    'colet': 'colecta', 'cabell': 'cabello', 'bulb': 'bulbo', 'puest': 'puesto', 'agent': 'agente',
    'etiolog': 'etiológica', 'fas': 'fase', 'resolut': 'resolutiva', 'cpntext': 'contexto', 'sept': 'septum',
    'linfagitis': 'linfangitis', 'febricul': 'febrícula', 'respons': 'respuesta', 'distribu': 'distribución',
    'broncogen': 'broncogénico', 'pediatr': 'pediatría', 'bronquioloectasi': 'bronquioloectasia', 'cinic': 'clínico',
    'infilitr': 'infiltrado', 'supradiafragmat': 'supradiafragmático', 'discartrosis': 'discartrosis', 'pared': 'pared',
    'grues': 'gruesa', 'acuerd': 'acuerdo', 'pinzament': 'pinzamiento', 'inflamaori': 'inflamatorio',
    'conplet': 'completo', 'tramabroncovascul': 'trama broncovascular', 'carec': 'carece', 'intersiticial': 'intersticial',
    'citologi': 'citología', 'esput': 'esputo', 'stents': 'stents', 'encontr': 'encontrar', 'arot': 'aorta',
    'pumnon': 'pulmón', 'atreci': 'atrésico', 'opacificacion': 'opacificación', 'acces': 'acceso',
    'dificult': 'dificultad', 'refer': 'referencia', 'nuemotorax': 'neumotórax', 'pehili': 'pélvica',
    'parietal': 'parietal', 'intraluminal': 'intraluminal', 'precis': 'precisa', 'poster': 'posterior', 'don': 'donde',
    'prerifer': 'periférico', '3seman': '3 semanas', 'pinzaminent': 'pinzamiento', 'pneumon': 'neumonía',
    'bronquiectasis': 'bronquiectasias', 'condesacion': 'condensación', 'mayori': 'mayoría', 'bors': 'bordes',
    'retrocardi': 'retrocardíaco', 'provoc': 'provoca', '49': '49', 'cicatrical': 'cicatrizal', 'ares': 'áreas',
    'hipodens': 'hipodensa', 'cavern': 'caverna', 'basalf': 'basal', 'p10': 'P10', 'espondiloartopati': 'espondiloartropatía',
    'caridomegali': 'cardiomegalia', 'tuberculosis': 'tuberculosis', 'intent': 'intento', 'acud': 'acudió',
    'servici': 'servicio', 'visuliz': 'visualización', 'unas': 'unas', 'cavid': 'cavidad', 'cl': 'clínica',
    'nic': 'nic', 'izqdas': 'izquierdas', 'alrededor': 'alrededor', 'revision': 'revisión', 'lob': 'lóbulo',
    'plat': 'plata', 'ai': 'aí', 'cifoescliosis': 'cifoescoliosis', 'toracoplasti': 'toracoplastia',
    'sinequi': 'sinequias', 'iinfrahili': 'infradiafragmático', 'intersitcioalveol': 'intersticioalveolar',
    'nuemoni': 'neumonía', 'ensid': 'enside', 'rt': 'radioterapia', 'intesticioalveol': 'intersticioalveolar',
    'neoplaci': 'neoplasia', 'va': 'vía', 'supon': 'supone', 'terapeut': 'terapéutico', 'pevi': 'peví',
    'hilio': 'hilio', 'etaman': 'estaman', 'nac': 'nacimiento', 'loe': 'LOE', 'itnersticioalveol': 'intersticioalveolar',
    'endocarditis': 'endocarditis', 'revaluacion': 'reevaluación', 'oncolog': 'oncológico', 'reelvant': 'relevante',
    'expoloracion': 'exploración', 'difumin': 'difuminado', 'razon': 'razón', 'segu': 'seguimiento', 'controland': 'controlando',
    'ltd': 'Ltda.', 'atalectasi': 'atelectasia', 'mandibul': 'mandíbula', 'indicari': 'indicaría', 'perilesional': 'perilesional',
    'hech': 'hecho', 'toracostomi': 'toracostomía', 'cerr': 'cerrada', 'persit': 'persiste', 'peg': 'peg', 'direct': 'directo',
    'apoy': 'apoyo', 'signfic': 'significativa', 'magnific': 'magnífica', 'escolioisis': 'escoliosis',
    'desarroll': 'desarrollo', 'anomal': 'anomalía', 'diafrgamat': 'diafragmático', 'izqdo': 'izquierdo',
    'eslcer': 'esclarecer', 'acual': 'actual', 'alesion': 'lesión', 'distension': 'distensión', 'colic': 'cólico',
    'artrosis': 'artrosis', 'vasos': 'vasos', 'hab': 'habrá', 'crepit': 'crepitación', 'hioatal': 'hiatal',
    'inferomedial': 'inferomedial', 'hepatomegali': 'hepatomegalia', 'corax': 'corazón', 'asuenci': 'ausencia',
    'periferi': 'periférico', 'correlacon': 'correlación', 'malformacion': 'malformación', 'aprovech': 'aprovechó',
    'estirp': 'estirpe', 'tromboembol': 'tromboembolismo', 'padec': 'padecimiento', 'ef': 'efecto',
    'interpretacion': 'interpretación', 'bronquiolitis': 'bronquiolitis', 'copndens': 'condensación',
    'diganost': 'diagnóstico', 'urgenci': 'urgencia', 'exfum': 'exfumador', 'familiar': 'familiar',
    'supr': 'súper', 'calcificad': 'calcificación', 'desaparecidoel': 'desaparecido el',
    'intersticioalvolar': 'intersticial alveolar', 'as': 'así', 'radiologic': 'radiológica',
    'reactivacion': 'reactivación', 'tb': 'tuberculosis', 'llss': 'límites', 'preci': 'precisa',
    'brocogram': 'broncograma', 'tto': 'tratamiento', '39': '39', 'intersci': 'intersticial',
    'aumet': 'aumento', 'inffiltr': 'infiltrado', 'significativasp': 'significativas', 'percutane': 'percutáneo',
    'adip': 'adiposo', 'dle': 'DLE', 'disficult': 'dificultad', 'respuest': 'respuesta', 'progresion': 'progresión',
    'mur': 'murmullo', 'estructural': 'estructural', 'preoperatori': 'preoperatorio',
    'aprecianmetastasis': 'aprecian metastasis', 'tipic': 'típica', 'precoz': 'precoz', 'estari': 'estarían',
    'amorf': 'amorfo', 'sig': 'sigue', 'institucion': 'institución', 'muc': 'mucosa', 'respir': 'respiratorio',
    'paremquimat': 'parequimatosa', 'qyu': 'que', 'oscur': 'oscuro', 'dificil': 'difícil', 'avis': 'avisar',
    'espald': 'espalda', 'senocostofrenicoizd': 'seno costo-frénico izquierdo', 'asmat': 'asmática',
    'tratari': 'trataría', 'tendri': 'tendría', 'pens': 'pensar', 'postneumoni': 'postneumonía',
    'margen': 'margen', 'disposicion': 'disposición', 'poryect': 'proyecta', 'burbuj': 'burbuja',
    'apropi': 'apropiado', 'solicitud': 'solicitud', 'mielodisplas': 'mielodisplasia', 'linfom': 'linfoma',
    'lustr': 'lustrosa', 'pareqnuim': 'parequimatosa', '2019': '2019', 'desconozc': 'desconoce',
    'disneic': 'disneica', 'carciomegali': 'cardiomegalia', 'radiologog': 'radiólogo', 'exist': 'existe',
    'asteni': 'astenia', 'asim': 'asimétrico', 'rinorre': 'rinorrea', 'veladur': 'veladura',
    'sobreanad': 'sobreanadida', 'impact': 'impacto', 'ingurgit': 'ingurgitación', 'necrotiz': 'necrotización',
    'problem': 'problema', 'informat': 'informativo', 'malest': 'malestar', 'general': 'general',
    'postradioterpi': 'postradioterapia', 'retrocrdiac': 'retrocardíaco', 'etioogi': 'etiología',
    'infrahil': 'infradiafragmático', 'describ': 'describe', 'hoy': 'hoy', 'desaparec': 'desapareció',
    'traduccion': 'traducción', 'estadificacion': 'estadificación', 'perssit': 'persiste', 'actitud': 'actitud',
    'nin': 'niño', 'hallag': 'hallazgo', 'extension': 'extensión', 'dese': 'deseo', 'sintomat': 'síntomas',
    'cardiotoraci': 'cardiotorácica', 'postrat': 'postratamiento', 'clras': 'claras', 'ayer': 'ayer',
    'desvi': 'desviación', 'degenerat': 'degenerativa', 'stent': 'stent', 'bili': 'bilateral',
    'hemimotorax': 'hemotórax', 'hallazgs': 'hallazgos', 'izquied': 'izquierdo', 'aportacion': 'aportación',
    'radioluc': 'radiolúcido', 'craneal': 'craneal', 'muell': 'muelle', 'cosal': 'costal',
    'pseuconodul': 'seudonódulo', 'infrahilii': 'infradiafragmático', 'tacs': 'TACs', 'hematom': 'hematoma',
    'aperci': 'aprecia', 'habitual': 'habitual', 'cuant': 'cuantitativa', 'solicitart': 'solicitará',
    'seguimient': 'seguimiento', 'canc': 'cáncer', 'lorax': 'lorazepam', 'reces': 'recesión',
    'quirurgi': 'quirúrgica', 'hiperlucent': 'hiperlucencia', 'asma': 'asma', 'diagnostic': 'diagnóstico',
    'ingres': 'ingreso', 'terc': 'tercer', 'condroesternal': 'condroesternal', 'detram': 'detram',
    'paract': 'parcial', 'uei': 'Uei', 'contralateral': 'contralateral', 'sigbnific': 'significativa',
    'sunsehmentari': 'suplementaria', 'bif': 'bífido', 'anomali': 'anomalía', 'dud': 'duda', 'hemorragi': 'hemorragia',
    'coment': 'comentario', 'apne': 'apnea', 'suen': 'sueño', 'atelectasis': 'atelectasis', 'mv': 'músculo',
    'endotraqueal': 'endotraqueal', '6to': 'sexto', 'acromioclavicul': 'acromioclavicular',
    'reabsorcion': 'reabsorción', 'car': 'carcinoma', 'etilogi': 'etilogía', 'desnsidad': 'densidad',
    'valoreis': 'valores', 'lux': 'luxación', 'expnes': 'expansión', 'alveolointesticial': 'alveolointersticial',
    'acromiohumeral': 'acromiohumeral', 'resolv': 'resolución', 'qued': 'quedó', 'indispens': 'indispensable',
    'signod': 'signos', 'plieg': 'pliegue', 'jlni': 'julio', 'activ': 'activa', 'correpond': 'corresponde',
    'diminucion': 'disminución', 'densod': 'densidad', 'parequimat': 'parequimatosa', 'hip': 'hipertensión',
    'insuflacion': 'insuflación', 'pard': 'pared', 'reinfeccion': 'reinfección', 'respiartori': 'respiratorio',
    'interval': 'intervalo', 'tiemp': 'tiempo', 'costectomi': 'costectomía', 'expand': 'expandir', 'restant': 'restante',
    'retocardiac': 'retrocardíaco', 'groser': 'grosero', 'esplen': 'esplénico', 'ingurgitacion': 'ingurgitación', 'condrocostal': 'condrocostal',
    'halalzg': 'hallazgo', 'artefactual': 'artefactual', 'civ': 'civ', 'costodifragmat': 'costodiafragmático',
    'estudiodel': 'estudio del', 'signs': 'signos', 'braquiocefal': 'braquiocefálico', 'favor': 'favor',
    'graci': 'gracias', 'cremaller': 'cremallera', 'estabil': 'estable', 'scheuerm': 'Scheuermann',
    'tub': 'tubo', 'paralel': 'paralelo', 'expansor': 'expansor', 'posrterior': 'posterior', 'infect': 'infecta',
    'msd': 'MSD', 'halalazg': 'hallazgo', 'monocameral': 'monocameral', 'suedonodul': 'seudonódulo',
    'compensatori': 'compensatorio', 'bilob': 'bilobulado', 'condral': 'condral', 'nostic': 'diagnóstico',
    'charnel': 'charnel', 'lumbosacr': 'lumbosacro', 'integr': 'integra', 'hipertrof': 'hipertrofia', 'pic': 'pico',
    'mii': 'mii', 'med': 'med', 'campan': 'campana', 'compromis': 'compromiso', 'rinitis': 'rinitis', 'alerg': 'alergia',
    'pobr': 'pobre', 'paralisis': 'parálisis', 'cosult': 'consulta', 'alambr': 'alambre', 'irrit': 'irritación',
    'detaman': 'detaman', 'alvelointersticial': 'alveolointersticial', 'octav': 'octava', 'cardiopat': 'cardiopatía',
    'colum': 'columna', '9cm': '9cm', 'cas': 'caso', 'lat': 'lateral', 'hai': 'hái', 'diaframat': 'diafragmático',
    'grastric': 'gástrico', 'dilat': 'dilata', 'distend': 'distendido', 'gastroparesi': 'gastroparesia',
    'vagal': 'vagal', 'nfiltr': 'infiltrado', 'peribornaquial': 'peribronquial', 'embol': 'embolismo',
    'septic': 'séptico', 'radial': 'radial', 'munec': 'muñeca', 'pelvis': 'pelvis', 'lordosis': 'lordosis',
    'coxofemoral': 'coxofemoral', 'efect': 'efecto', 'estan': 'están', 'escolisis': 'escoliosis',
    'noduor': 'nódulo', 'mantien': 'mantiene', 'foram': 'foramen', 'acentu': 'acentuado', 'sistem': 'sistema',
    'acromioclavicular': 'acromioclavicular', 'sigm': 'sigmoide', 'teoric': 'teórico', 'cardic': 'cardíaco',
    'hemangiom': 'hemangioma', 'irregular': 'irregular', 'exuber': 'exuberante', 'inflamatoris': 'inflamatorias',
    'hipoplasi': 'hipoplasia', 'separacion': 'separación', 'paraespinal': 'paraespinal', 'moment': 'momento', 'depend': 'depende',
    'descendent': 'descendente', 'consig': 'consigo', 'estrictura': 'estructura', 'incomplet': 'incompleta', 'postquirurg': 'postquirurgico',
    'sintomatologi': 'sintomatología', 'respiratori': 'respiratorio', 'med': 'medio', 'ascendent': 'ascendente', 'ultim': 'ultimo',
    'cabl': 'cable', 'toracici': 'toracico'
}

# %%
# Función para completar palabras usando spaCy
def completar_palabras_nlp(texto):
    doc = nlp(texto)
    palabras_completas = [palabras_posibles.get(token.text.lower(), token.text) for token in doc]
    return ' '.join(palabras_completas)

# %%
# Nombre de la columna a completar
nombre_columna = 'Report'  # Reemplaza con el nombre correcto

# Aplicar la función a la columna
df[nombre_columna] = df[nombre_columna].apply(lambda x: completar_palabras_nlp(x) if pd.notnull(x) else x)

# Guardar el nuevo DataFrame en un nuevo archivo CSV
nuevo_file_path = '/content/metadato_img_frontales_completo.csv'
df.to_csv(nuevo_file_path, index=False)

# %%
df_2 = pd.read_csv('/content/metadato_img_frontales_completo.csv')

# %%
df_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7973 entries, 0 to 7972
# Data columns (total 36 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Unnamed: 0                       7973 non-null   int64
#  1   ImageID                          7973 non-null   object
#  2   ImageDir                         7973 non-null   int64
#  3   StudyDate_DICOM                  7973 non-null   int64
#  4   StudyID                          7973 non-null   object
#  5   PatientID                        7973 non-null   object
#  6   PatientBirth                     7973 non-null   float64
#  7   PatientSex_DICOM                 7973 non-null   object
#  8   ViewPosition_DICOM               4854 non-null   object
#  9   Projection                       7973 non-null   object
#  10  MethodProjection                 7973 non-null   object
#  11  Pediatric                        7973 non-null   object
# ...

# %%
df_2['ImageID']
# Out:
# 0       20536686640136348236148679891455886468_k6ga29.png
# 1       135803415504923515076821959678074435083_fzis7b...
# 2       113855343774216031107737439268243531979_3k951l...
# 3       105529804483623054726294337265160703666_6zn76a...
# 4       238285621348398466668514178112618553012_a7k6dv...
#                               ...
# 7968    279662114590302415844085481211050220071_8i3m80...
# 7969    295371829347306431535788866421374380793_01vaqx...
# 7970    278261127874865239055858023529440516978_gg550t...
# 7971    173842064623268686813518068947014345283_nzpdtj...
# 7972    204963721473785821095257157327085343502_mzh4to...
# Name: ImageID, Length: 7973, dtype: object

# %%
df_2['Report'][1000]
# Out:
# '  calcificación supraespinoso derecho . sin hallazgo radiológico intersticial .'

# %%
df_2['ImageID']
# Out:
# 0       20536686640136348236148679891455886468_k6ga29.png
# 1       135803415504923515076821959678074435083_fzis7b...
# 2       113855343774216031107737439268243531979_3k951l...
# 3       105529804483623054726294337265160703666_6zn76a...
# 4       238285621348398466668514178112618553012_a7k6dv...
#                               ...
# 7968    279662114590302415844085481211050220071_8i3m80...
# 7969    295371829347306431535788866421374380793_01vaqx...
# 7970    278261127874865239055858023529440516978_gg550t...
# 7971    173842064623268686813518068947014345283_nzpdtj...
# 7972    204963721473785821095257157327085343502_mzh4to...
# Name: ImageID, Length: 7973, dtype: object

# %%
# Valor que deseas buscar
valor_busqueda = '323261621534853356815517326665848631154_861oqr.png'

# Buscar en la columna 'Columna_Busqueda'
fila_encontrada = df_2[df_2['ImageID'] == valor_busqueda]

# Mostrar la fila encontrada
print("Fila encontrada:\n", fila_encontrada)
# Out:
# Fila encontrada:
#        Unnamed: 0                                            ImageID  ImageDir  \
# 3667        6764  323261621534853356815517326665848631154_861oqr...         2
#
#       StudyDate_DICOM                                  StudyID  \
# 3667         20151120  323261621534853356815517326665848631154
#
#                                     PatientID  PatientBirth PatientSex_DICOM  \
# 3667  241026653254781823360733804549513196507        1940.0                M
#
#      ViewPosition_DICOM Projection  ... ExposureTime  \
# 3667    POSTEROANTERIOR         PA  ...         10.0
#
#      RelativeXRayExposure_DICOM ReportID  \
# 3667                        NaN  5034942
#
#                                                  Report MethodLabel  \
# 3667    engrosamiento pleural biapical con tracto pl...   Physician
#
#                                                  Labels  \
# 3667  ['aortic elongation', 'chronic changes', 'apic...
#
# ...

# %%
df_2['Unnamed: 0']
# Out:
# 0           0
# 1           2
# 2           3
# 3          12
# 4          14
#         ...
# 7968    38934
# 7969    38955
# 7970    38958
# 7971    38964
# 7972    39011
# Name: Unnamed: 0, Length: 7973, dtype: int64

# %%
# Ordenar el DataFrame por la columna 'ImageID'
df_ordenado = df_2.sort_values(by='ImageID')

# Guardar el DataFrame ordenado en un nuevo archivo CSV
df_ordenado.to_csv('/content/date_ordenados.csv', index=False)

print("El archivo CSV se ha ordenado alfabéticamente según la columna 'ImageID'.")
# Out:
# El archivo CSV se ha ordenado alfabéticamente según la columna 'ImageID'.

# %%
df_3 = pd.read_csv('/content/date_ordenados.csv')

# %%
df_3['ImageID'].tolist()
# Out:
# ['100035238701184647172015593785663345624_vb6v1o.png',
#  '100040356313492993300375944915457919287_gfe8ds.png',
#  '100040356313492993300375944915457919287_gupf94.png',
#  '100069103068753688347522093561206841448_7197k3.png',
#  '100081820231385537397079729591266436694_8o3uj2.png',
#  '100127962438106734621148265078974688397_nqkpyr.png',
#  '100171984015994193562581691034118023629_370g35.png',
#  '100189276695524274872812056380542104060_5nnxx1.png',
#  '100208382776748673701423299557693976504_7znfv5.png',
#  '100231819761483411315795852717438780587_h963fu.png',
#  '100299747859432627610047515402077936903_6fel4z.png',
#  '100305638315058293194627488207514098468_p8ea27.png',
#  '100305638315058293194627488207514098468_q7j8k4.png',
#  '100327202203764340510982726224209200626_qepu0e.png',
#  '100330613357773192416915301158778783830_v6g44r.png',
#  '100347822010870106476883475407418302816_evsevn.png',
#  '100360992970443012139948853258191567510_orx7ef.png',
# ...

# %%
df_3.head(1)
# Out:
#    Unnamed: 0                                            ImageID  ImageDir  \
# 0        5922  100035238701184647172015593785663345624_vb6v1o...         1
#
#    StudyDate_DICOM                                  StudyID  \
# 0         20161227  100035238701184647172015593785663345624
#
#                                  PatientID  PatientBirth PatientSex_DICOM  \
# 0  156570607900599726776253653052596685981        1939.0                M
#
#   ViewPosition_DICOM Projection  ... ExposureTime RelativeXRayExposure_DICOM  \
# 0                NaN         PA  ...          0.0                      398.0
#
#   ReportID                                             Report MethodLabel  \
# 0  5292775     cardiomegalia . signo radiológico EPOC . ma...   Physician
#
#                                         Labels  \
# 0  ['COPD signs', 'pacemaker', 'cardiomegaly']
#
#                                        Localizations  \
# 0  ['loc cardiac', 'loc subclavian vein', 'loc le...
#
# ...
